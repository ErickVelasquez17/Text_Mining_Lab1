# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
original = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Text Mining/Lab2/FotoPapaLab.jpg")
original = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
plt.imshow(original)
plt.show()

# %%
def contorno_imagen(imagen):
    gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
    gris = cv2.cvtColor(gris, cv2.COLOR_BGR2GRAY)
    gauss = cv2.GaussianBlur(gris,(5,5),0)
    canny = cv2.Canny(imagen, 100, 100)
    (contornos,_) = cv2.findContours(canny.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    cv2.drawContours (imagen, contornos, -1, (0,255,0), 3)
    canny = cv2.cvtColor(canny, cv2.COLOR_BGR2RGB)
    cv2.drawContours(canny, contornos,  -1, (0,255,255), 3)
    gauss = cv2.cvtColor(gauss, cv2.COLOR_BGR2RGB)
    cv2.drawContours(gauss, contornos, -1, (0,255,0), 3)
    print ("Original")
    plt.imshow(original)
    plt.show()
    print ("Gauss")
    plt.imshow(gauss)
    plt.show()
    print ("Canny")
    plt.imshow(canny)
    plt.show()
    #image = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Text Mining/Lab2/rayosX.jpg")
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _,th = cv2.threshold(gray,100,255,cv2.THRESH_BINARY)
    img,contornos,hierarchy = cv2.findContours(th, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    cv2.drawContours(imagen, contornos1, -1, (0,255,0), 2)
    print ('hierarchy=',hierarchy)
    print ('len(contornos1[2])=',len(contornos1[2]))
    print ('len(contornos2[2])=',len(contornos2[2]))
    cv2.imshow('imagen',imagen)
    cv2.imshow('th',th)

# %%
original = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Text Mining/Lab2/papa13.jpeg")
original = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
contorno_imagen(original)
# Out:
# Original
# Gauss
# Canny
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-522fd8b8abe7> in <module>
#       1 original = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Text Mining/Lab2/papa13.jpeg")
#       2 original = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
# ----> 3 contorno_imagen(original)
#
# <ipython-input-50-8c82f5f65644> in contorno_imagen(imagen)
#      20     plt.show()
#      21     #image = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Text Mining/Lab2/rayosX.jpg")
# ---> 22     gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#      23     _,th = cv2.threshold(gray,100,255,cv2.THRESH_BINARY)
#      24     img,contornos,hierarchy = cv2.findContours(th, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
#
# NameError: name 'image' is not defined
